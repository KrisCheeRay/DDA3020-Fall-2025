# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
features_t0 = ["E2", "E3", "M1", "M9", "M11", "M13", "P2", "P5", "P8", "P10", "P11", "S2", "S3", "S8", "V7", "V9", "V10"]
features_t1 = features_t0 + ["E19", "M12", "S5", "V13"]

# %%
f_ic_ir = pd.read_pickle("Analysis/ic_ir_overall.pkl")

# %%
features_t0 = f_ic_ir.droplevel(0).loc[features_t0].abs().sort_values(by=("Rank IR", 1), ascending=False).index.tolist()
features_t1 = f_ic_ir.droplevel(0).loc[features_t1].abs().sort_values(by=("Rank IR", 1), ascending=False).index.tolist()

# %%
f_corr = pd.read_pickle("Analysis/f_corr_overall.pkl")
f_rank_corr = pd.read_pickle("Analysis/f_rank_corr_overall.pkl")

# %%
f_corr.droplevel(0).droplevel(0, axis=1).loc[features_t0, features_t0]
# Out:
# Feature        E2        E3       P11        P2       P10        M9        S8  \
# Feature
# E2            1.0  0.992693   0.98427 -0.979744  0.763076  0.794303  0.771948
# E3       0.992693       1.0  0.984191 -0.970783  0.789224  0.766686  0.781316
# P11       0.98427  0.984191       1.0 -0.974023  0.786494   0.80441   0.80224
# P2      -0.979744 -0.970783 -0.974023       1.0 -0.762391 -0.796362 -0.761557
# P10      0.763076  0.789224  0.786494 -0.762391       1.0  0.601078  0.677952
# M9       0.794303  0.766686   0.80441 -0.796362  0.601078       1.0  0.651842
# S8       0.771948  0.781316   0.80224 -0.761557  0.677952  0.651842       1.0
# M1      -0.748829 -0.756635 -0.792293  0.750439 -0.724354 -0.682228 -0.717891
# M11     -0.710476 -0.681982 -0.718514  0.712285 -0.541801 -0.781919 -0.696505
# M13     -0.520784 -0.554388 -0.556812  0.521496 -0.559032 -0.391054 -0.613215
# P8       0.639024  0.664761  0.656467  -0.62902  0.754973  0.493327  0.464576
# P5       0.501852  0.503476  0.528828  -0.48574  0.470786  0.408257  0.484371
# V9      -0.674922 -0.698605 -0.712706  0.680707 -0.708112 -0.561263 -0.654349
# V7      -0.665581 -0.689424 -0.704669  0.669794 -0.703022 -0.557469 -0.628996
# V10     -0.683601 -0.706638 -0.720317  0.689739 -0.710738 -0.562504  -0.66758
# S2        0.60228  0.604655  0.639888 -0.599067  0.555417  0.526035  0.816281
# S3       0.572745  0.577328  0.603758 -0.567894  0.543227   0.54882   0.78389
#
# Feature        M1       M11       M13        P8        P5        V9        V7  \
# Feature
# E2      -0.748829 -0.710476 -0.520784  0.639024  0.501852 -0.674922 -0.665581
# E3      -0.756635 -0.681982 -0.554388  0.664761  0.503476 -0.698605 -0.689424
# P11     -0.792293 -0.718514 -0.556812  0.656467  0.528828 -0.712706 -0.704669
# P2       0.750439  0.712285  0.521496  -0.62902  -0.48574  0.680707  0.669794
# P10     -0.724354 -0.541801 -0.559032  0.754973  0.470786 -0.708112 -0.703022
# M9      -0.682228 -0.781919 -0.391054  0.493327  0.408257 -0.561263 -0.557469
# S8      -0.717891 -0.696505 -0.613215  0.464576  0.484371 -0.654349 -0.628996
# M1            1.0  0.584983   0.60582 -0.637972  -0.46357  0.829915  0.825458
# M11      0.584983       1.0  0.425249 -0.404431  -0.46786  0.492722  0.480207
# M13       0.60582  0.425249       1.0 -0.434001 -0.376176  0.681753  0.611632
# P8      -0.637972 -0.404431 -0.434001       1.0  0.367746 -0.643796 -0.638716
# P5       -0.46357  -0.46786 -0.376176  0.367746       1.0 -0.456269 -0.449734
# V9       0.829915  0.492722  0.681753 -0.643796 -0.456269       1.0  0.972869
# V7       0.825458  0.480207  0.611632 -0.638716 -0.449734  0.972869       1.0
# V10      0.819999  0.498917   0.73147 -0.634301 -0.454247  0.985093  0.934735
# S2      -0.646274 -0.575842 -0.479902  0.371657  0.509695  -0.62088 -0.619196
# S3      -0.607959 -0.522599 -0.394849  0.355206  0.410005 -0.544337 -0.555806
#
# Feature       V10        S2        S3
# Feature
# E2      -0.683601   0.60228  0.572745
# E3      -0.706638  0.604655  0.577328
# P11     -0.720317  0.639888  0.603758
# P2       0.689739 -0.599067 -0.567894
# P10     -0.710738  0.555417  0.543227
# M9      -0.562504  0.526035   0.54882
# S8       -0.66758  0.816281   0.78389
# M1       0.819999 -0.646274 -0.607959
# M11      0.498917 -0.575842 -0.522599
# M13       0.73147 -0.479902 -0.394849
# P8      -0.634301  0.371657  0.355206
# P5      -0.454247  0.509695  0.410005
# V9       0.985093  -0.62088 -0.544337
# V7       0.934735 -0.619196 -0.555806
# V10           1.0 -0.605691  -0.52217
# S2      -0.605691       1.0  0.810284
# S3       -0.52217  0.810284       1.0

# %%
f_corr_t0 = f_corr.droplevel(0).droplevel(0, axis=1).loc[features_t0, features_t0]
f_corr_t1 = f_corr.droplevel(0).droplevel(0, axis=1).loc[features_t1, features_t1]

# %%
plt.figure(figsize=(25, 15))
sns.heatmap(f_corr_t0.astype(float), 
            annot=True, 
            cmap='RdBu_r',
            center=0,
            square=True,
            fmt=".2f",
            cbar_kws={"shrink": .8})

plt.title('Rank Correlation Matrix Heatmap', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 15))
sns.heatmap(f_corr_t1.astype(float), 
            annot=True, 
            cmap='RdBu_r',
            center=0,
            square=True,
            fmt=".2f",
            cbar_kws={"shrink": .8})

plt.title('Rank Correlation Matrix Heatmap', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
valid_features_t0 = []
valid = [True] * len(features_t0)
for i in range(len(features_t0)):
    for j in range(i):
        if abs(f_corr_t0.iloc[i, j]) > 0.7 and valid[j]:
            valid[i] = False
    if valid[i]:
        valid_features_t0.append(features_t0[i])
        
valid_features_t1 = []
valid = [True] * len(features_t1)
for i in range(len(features_t1)):
    for j in range(i):
        if abs(f_corr_t1.iloc[i, j]) > 0.7 and valid[j]:
            valid[i] = False
    if valid[i]:
        valid_features_t1.append(features_t1[i])

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(f_corr_t1.loc[valid_features_t0, valid_features_t0].astype(float), 
            annot=True, 
            cmap='RdBu_r',
            center=0,
            square=True,
            fmt=".2f",
            cbar_kws={"shrink": .8})

plt.title('Rank Correlation Matrix Heatmap After Adjustment', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(f_corr_t1.loc[valid_features_t1, valid_features_t1].astype(float), 
            annot=True, 
            cmap='RdBu_r',
            center=0,
            square=True,
            fmt=".2f",
            cbar_kws={"shrink": .8})

plt.title('Rank Correlation Matrix Heatmap After Adjustment', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
valid_features_t1
# Out:
# ['E2', 'M13', 'P8', 'P5', 'V9', 'S2', 'M12', 'S5']

# %%
train = pd.read_csv('train.csv', index_col=0)
train_input = train.loc[:, valid_features_t1 + ["forward_returns"]]
train_input.to_csv('train_feature_selected.csv')
